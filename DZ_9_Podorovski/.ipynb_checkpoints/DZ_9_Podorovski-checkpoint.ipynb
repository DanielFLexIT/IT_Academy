# %%
import pandas as pd
import numpy as np
import tqdm
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm
import statsmodels.tsa.api as smt
from statsmodels.tsa.stattools import adfuller
from scipy.stats import boxcox
from math import sqrt
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %% [markdown]
# # Исследуем месячное производство пива в Австрии

# %%
beer = pd.read_excel('Задания_1_2.xlsx', index_col = False)
beer
# Out:
#             Date      series1
# 0     2015-01-01  1006.699649
# 1     2015-01-02  3197.751826
# 2     2015-01-03  3217.491035
# 3     2015-01-04  2151.573759
# 4     2015-01-05  4243.929892
# ...          ...          ...
# 1637  2019-06-26  4007.059387
# 1638  2019-06-27  4836.106157
# 1639  2019-06-28  4895.323783
# 1640  2019-06-29  4086.016222
# 1641  2019-06-30  3572.796793
#
# [1642 rows x 2 columns]

# %%
beerProd = beer['series1']

# %% [markdown]
# # В качестве модели Machine Learning возьмем Random Forest Regressor

# %%
def prepareData(data, lag_start=5, lag_end=20, test_size=0.15):
    
    data = pd.DataFrame(data.copy())
    test_index = int(len(data)*(1-test_size))
    for i in range(lag_start, lag_end):
        data["lag_{}".format(i)] = data['Monthly beer production'].shift(i)
        
    data = data.dropna()
    data = data.reset_index(drop=True)
    data = data.drop(["Month"], axis=1)
    X_train = data.loc[:test_index].drop(["Monthly beer production"], axis=1)
    y_train = data.loc[:test_index]["Monthly beer production"]
    X_test = data.loc[test_index:].drop(["Monthly beer production"], axis=1)
    y_test = data.loc[test_index:]["Monthly beer production"]
    
    return X_train, X_test, y_train, y_test

# %%
X_train, X_test, y_train, y_test = prepareData(beer, lag_start=1, lag_end=25, test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Monthly beer production'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-28b5ccbae94d> in <module>
# ----> 1 X_train, X_test, y_train, y_test = prepareData(beer, lag_start=1, lag_end=25, test_size=0.3)
#
# <ipython-input-6-77d2bcb131ad> in prepareData(data, lag_start, lag_end, test_size)
#       4     test_index = int(len(data)*(1-test_size))
#       5     for i in range(lag_start, lag_end):
# ----> 6         data["lag_{}".format(i)] = data['Monthly beer production'].shift(i)
#       7
#       8     data = data.dropna()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Monthly beer production'

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state = 42)
rf.fit(X_train, y_train)
prediction_rf = rf.predict(X_test)

plt.figure(figsize=(14, 8))
plt.plot(prediction, "r", label="prediction")
plt.plot(y_test.values, label="actual")
plt.legend(loc="best")
plt.title("Random Forest")
plt.grid(True);

# %% [markdown]
# # Ревизорро огорчило, но линейная регрессия отработала ещё хуже, нужен на подмогу гридсерч

# %%
mean_squared_error(y_test, prediction_rf, squared=False)
# Out:
# 12.71988903782002

# %% [markdown]
# # Hidden Markov Model

# %%
from hmmlearn.hmm import GaussianHMM
values = beerProd.values.reshape(-1,1)
for n in range(1, 18):
    model = GaussianHMM(n_components=n,
                        covariance_type="diag",
                        n_iter=1000)
    model.fit(values)
    print (n, model.score(values))
# Out:
# 1 -2349.7898427918853
# 2 -2130.681610496574
# 3 -2085.061940640089
# 4 -2048.241308764795
# 5 -2025.718389895706
# 6 -2002.8737988719154
# 7 -1995.6162586360144
# 8 -1974.4428111504278
# 9 -1962.906440092703
# 10 -1949.8370069322293
# 11 -1943.3869239367746
# 12 -1931.8053977811558
# 13 -1918.5549034599205
# 14 -1914.6139261770334
# 15 -1894.1544890208022
# 16 -1884.388791163319
# 17 -1884.7756366358058

# %%
model = GaussianHMM(n_components=17,
                        covariance_type="diag",
                        n_iter=1000)
model.fit(values)
labels = model.predict(values)
means = np.zeros_like(values)
for i in range(model.n_components):
    means[labels == i] = model.means_[i]
    
plt.figure(figsize=(12, 6))
plt.plot(values)
plt.plot(means, linewidth=2)

# %%
test_index = values.shape[0] - 40
train = values[:test_index]
test = values[test_index:]

# %%
model = GaussianHMM(n_components=17,
                        covariance_type="diag",
                        n_iter=1500)
model.fit(train)
# Out:
# GaussianHMM(n_components=17, n_iter=1500)

# %%
labels = model.predict(test)
means = np.zeros_like(test)
for i in range(model.n_components):
    means[labels == i] = model.means_[i]
    
plt.figure(figsize=(12, 6))
plt.plot(test)
plt.plot(means, linewidth=2)

# %% [markdown]
# # Визуально выглядит лучше

# %%
mean_squared_error(means, test, squared = False)
# Out:
# 12.378863039966975

# %% [markdown]
# # Проверяем ряд на стационарность

# %%
# проверка стационарности Дики-Фуллера
def test_stationarity(timeseries):
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for [key, value] in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

# %%
# Time-series plot
def tsplot(y, lags=None, figsize=(14, 8), style='bmh'):
    test_stationarity(y)
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):
        plt.figure(figsize=figsize)
        layout = (5, 1)
        ts_ax = plt.subplot2grid(layout, (0, 0), rowspan=2)
        acf_ax = plt.subplot2grid(layout, (2, 0))
        pacf_ax = plt.subplot2grid(layout, (3, 0))
        qq_ax = plt.subplot2grid(layout, (4, 0))

        y.plot(ax=ts_ax, color='blue', label='Or')
        ts_ax.set_title('Original')

        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.05)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.05)
        # qqplot для определения нормальности распределения остатков
        sm.qqplot(y, line='s', ax=qq_ax)
        
        plt.tight_layout()
    return

# %%
test_stationarity(beerProd)
tsplot(beerProd)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.282661
# p-value                          0.177621
# #Lags Used                      17.000000
# Number of Observations Used    458.000000
# Critical Value (1%)             -3.444709
# Critical Value (5%)             -2.867871
# Critical Value (10%)            -2.570142
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.282661
# p-value                          0.177621
# #Lags Used                      17.000000
# Number of Observations Used    458.000000
# Critical Value (1%)             -3.444709
# Critical Value (5%)             -2.867871
# Critical Value (10%)            -2.570142
# dtype: float64

# %% [markdown]
# # Ряд нестационарен, также в нём есть сезонность, поэтому сделаем небольшие манипуляции для исправления ситуации

# %%
beerProd_changed = boxcox(beerProd, 1)
beerProd_changed = beerProd_changed[12:] - beerProd_changed[:-12]
beerProd_changed = np.diff(beerProd_changed, 1)

# %%
tsplot(beerProd_changed)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.633216e+00
# p-value                        5.681339e-14
# #Lags Used                     1.600000e+01
# Number of Observations Used    4.460000e+02
# Critical Value (1%)           -3.445097e+00
# Critical Value (5%)           -2.868042e+00
# Critical Value (10%)          -2.570233e+00
# dtype: float64

# %% [markdown]
# # Ряд стал стационарным, можно применять Arima

# %%
arima_model = smt.ARIMA(beerProd_changed, order=(5,0,3)).fit(method='mle', trend='nc')
tsplot(arima_model.resid)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.898903
# p-value                          0.000035
# #Lags Used                      18.000000
# Number of Observations Used    444.000000
# Critical Value (1%)             -3.445164
# Critical Value (5%)             -2.868072
# Critical Value (10%)            -2.570249
# dtype: float64

# %%
with plt.style.context('bmh'):
    plt.figure(figsize=(14,8))
    ax = plt.axes()
    plt.plot(arima_model.predict(len(beerProd_changed[:-31]),len(beerProd_changed[:-31])+30),color="blue",label='Preds')
    plt.plot(beerProd_changed[-31:], color='red', label='Series')
    plt.legend()
    plt.show()

# %%
np.sqrt(np.sum((arima_model.predict(len(beerProd_changed[:-31]),len(beerProd_changed[:-31])+30)-beerProd_changed[-31:])**2))/30
# Out:
# 2.002775341137395

# %% [markdown]
# # Вывод: в конкретно данном датасете лучше всего справилась с работой Arima, но самый глобальный вывод: предсказать производство пива в Австрии - не самое благодарное занятие. С 1950 года производственные мощности, естественно увеличились, также на производство очень влияет урожайность и другие факторы. Пейте пиво!
