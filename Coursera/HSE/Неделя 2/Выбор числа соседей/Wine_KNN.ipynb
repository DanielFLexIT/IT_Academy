# %%
import pandas as pd

# %%
columns = [
    "Class",
    "Alcohol",
    "Malic acid",
    "Ash",
    "Alcalinity of ash",
    "Magnesium",
    "Total phenols",
    "Flavanoids",
    "Nonflavanoid phenols",
    "Proanthocyanins",
    "Color intensity",
    "Hue",
    "OD280/OD315 of diluted wines",
    "Proline",
]
data = pd.read_csv('wine.data', names = columns, index_col = False)

# %%
data
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
y = data['Class']
X = data
del X['Class']

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import KFold, cross_val_score

# %%
fold = KFold(shuffle = True, random_state = 42)

# %%
scores = []
for k in range(1,51):
    clf = KNeighborsClassifier(n_neighbors = k)
    score = cross_val_score(clf, X, y, cv = fold, scoring = 'accuracy').mean()
    scores.append(score)

# %%
scores
# Out:
# [0.7304761904761905,
#  0.6625396825396825,
#  0.7082539682539682,
#  0.6577777777777778,
#  0.6746031746031746,
#  0.6742857142857144,
#  0.68,
#  0.6799999999999999,
#  0.7023809523809523,
#  0.6801587301587302,
#  0.7025396825396826,
#  0.6966666666666667,
#  0.6909523809523809,
#  0.6793650793650794,
#  0.701904761904762,
#  0.6795238095238096,
#  0.7015873015873015,
#  0.6795238095238095,
#  0.6793650793650793,
#  0.6909523809523809,
#  0.7019047619047619,
#  0.6965079365079364,
#  0.7020634920634921,
#  0.7076190476190476,
#  0.7019047619047619,
#  0.6965079365079365,
#  0.6963492063492064,
#  0.7079365079365079,
#  0.7134920634920634,
#  0.7079365079365079,
#  0.690952380952381,
#  0.7134920634920634,
#  0.7134920634920634,
#  0.7246031746031747,
#  0.7246031746031747,
#  0.7134920634920636,
#  0.7134920634920634,
#  0.7134920634920634,
#  0.7079365079365079,
#  0.7077777777777777,
#  0.7134920634920634,
#  0.7077777777777777,
#  0.7077777777777777,
#  0.7077777777777777,
# ...

# %%
best_score = max(scores)

# %%
best_k = scores.index(best_score) + 1

# %%
print(best_k, best_score)
# Out:
# 1 0.7304761904761905

# %%
from sklearn.preprocessing import scale

# %%
X_scaled = scale(X)

# %%
scores_scaled = []
for k in range(1,51):
    clf = KNeighborsClassifier(n_neighbors = k)
    score = cross_val_score(clf, X_scaled, y, cv = fold, scoring = 'accuracy').mean()
    scores_scaled.append(score)

# %%
best_score_scaled = max(scores_scaled)
best_k_scaled = scores_scaled.index(best_score_scaled) + 1
print(best_k_scaled, best_score_scaled)
# Out:
# 29 0.9776190476190475
